# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (12,8)
# %matplotlib inline

# %%
σ =  2
μ = 6

v = np.random.normal(σ, μ, size=10000)

# %%
#sns.distplot(v)
plt.plot(v)

# %%
np.random.poisson?

# %% [markdown]
# math:: $f(k; \lambda)=\frac{\lambda^k e^{-\lambda}}{k!}$
#
# roots: $\frac{-b}{2a}$
